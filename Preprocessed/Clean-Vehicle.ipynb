# %%
import pandas as pd
import random
import math
import numpy as np

# %%
df = pd.read_csv('data/Vehicle.csv', delimiter=",",
                 encoding="iso-8859-1", low_memory=False)

# %%
df.head()
# Out:
#     ID Age_Band_of_Driver  Age_of_Vehicle Driver_Home_Area_Type  \
# 0  A-1            26 - 35             3.0            Urban area
# 1  A-2            26 - 35            37.0            Urban area
# 2  A-3            26 - 35             4.0                 Rural
# 3  A-4            66 - 75            95.0            Urban area
# 4  A-5            26 - 35             1.0            Urban area
#
#    Driver_IMD_Decile  Engine_Capacity_.CC. Hit_Object_in_Carriageway  \
# 0                4.0                1588.0                       NaN
# 1                3.0                   NaN                       NaN
# 2                NaN                 998.0                       NaN
# 3                NaN                   NaN                       NaN
# 4                4.0                 124.0                       NaN
#
#   Hit_Object_off_Carriageway     Journey_Purpose_of_Driver  \
# 0                        NaN  Data missing or out of range
# ...

# %%
df.isna().sum()
# Out:
# ID                                        0
# Age_Band_of_Driver                        0
# Age_of_Vehicle                            0
# Driver_Home_Area_Type                     0
# Driver_IMD_Decile                    270659
# Engine_Capacity_.CC.                  94129
# Hit_Object_in_Carriageway           1006308
# Hit_Object_off_Carriageway           954497
# Journey_Purpose_of_Driver                 0
# Junction_Location                         0
# make                                      0
# model                                154415
# Propulsion_Code                       77778
# Sex_of_Driver                             0
# Skidding_and_Overturning             897826
# Towing_and_Articulation                   0
# Vehicle_Leaving_Carriageway               0
# Vehicle_Location.Restricted_Lane        205
# Vehicle_Manoeuvre                         0
# Vehicle_Reference                         0
# Vehicle_Type                              0
# ...

# %%
df[['X1st_Point_of_Impact']].tail(60)
# Out:
#         X1st_Point_of_Impact
# 1048515                Front
# 1048516                Front
# 1048517                Front
# 1048518       Did not impact
# 1048519             Nearside
# 1048520              Offside
# 1048521              Offside
# 1048522                Front
# 1048523              Offside
# 1048524                Front
# 1048525                 Back
# 1048526                 Back
# 1048527             Nearside
# 1048528              Offside
# 1048529                Front
# 1048530                Front
# 1048531              Offside
# 1048532                 Back
# 1048533                Front
# 1048534              Offside
# 1048535       Did not impact
# 1048536       Did not impact
# 1048537                Front
# 1048538              Offside
# 1048539                Front
# 1048540                Front
# 1048541              Offside
# 1048542                Front
# 1048543              Offside
# 1048544             Nearside
# 1048545                Front
# ...

# %%
# Xu ly Age_Band_of_Driver
unique_values = df['Age_Band_of_Driver'].dropna().unique()

# Random các giá trị từ cột
random_values = np.random.choice(
    unique_values, size=df['Age_Band_of_Driver'].isnull().sum())
df['Age_Band_of_Driver'].fillna(value=pd.Series(random_values,
                                                index=df.index[df['Age_Band_of_Driver'].isnull()]), inplace=True)


lst_Age_Band_Of_Driver = list(unique_values)
lst_remove = ['Data missing or out of range',
              '15-Nov', '10-Jun', '0 - 5', 'Not known', 'None']
for value in lst_remove:
    if value in lst_Age_Band_Of_Driver:
        lst_Age_Band_Of_Driver.remove(value)

for i, v in df.iterrows():
    if v['Age_Band_of_Driver'] in lst_remove:
        df.loc[i, 'Age_Band_of_Driver'] = random.choice(lst_Age_Band_Of_Driver)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12636\155909252.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age_Band_of_Driver'].fillna(value=pd.Series(random_values,

# %%
# Xu ly Age_of_Vehicle
lst_Age_of_Vehicle = list(df['Age_of_Vehicle'].dropna().unique())
for i, v in df.iterrows():
    if math.isnan(v['Age_of_Vehicle']):
        df.loc[i, 'Age_of_Vehicle'] = random.choice(lst_Age_of_Vehicle)

# %%
# Xu ly Driver_Home_Area_Type
unique_values = df['Driver_Home_Area_Type'].dropna().unique()

# Random các giá trị từ cột
random_values = np.random.choice(
    unique_values, size=df['Driver_Home_Area_Type'].isnull().sum())
df['Driver_Home_Area_Type'].fillna(value=pd.Series(random_values,
                                                   index=df.index[df['Driver_Home_Area_Type'].isnull()]), inplace=True)


lst_Driver_Home_Area_Type = list(unique_values)
for value in lst_remove:
    if value in lst_Driver_Home_Area_Type:
        lst_Driver_Home_Area_Type.remove(value)

for i, v in df.iterrows():
    if v['Driver_Home_Area_Type'] in lst_remove:
        df.loc[i, 'Driver_Home_Area_Type'] = random.choice(
            lst_Driver_Home_Area_Type)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12636\802012976.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Driver_Home_Area_Type'].fillna(value=pd.Series(random_values,

# %%
# Xu ly Sex_of_Driver
unique_values = df['Sex_of_Driver'].dropna().unique()
# Random các giá trị từ cột
random_values = np.random.choice(
    unique_values, size=df['Sex_of_Driver'].isnull().sum())
df['Sex_of_Driver'].fillna(value=pd.Series(random_values,
                                                   index=df.index[df['Sex_of_Driver'].isnull()]), inplace=True)

lst_Sex_of_Driver = list(unique_values)
for value in lst_remove:
    if value in lst_Sex_of_Driver:
        lst_Sex_of_Driver.remove(value)

for i, v in df.iterrows():
    if v['Sex_of_Driver'] in lst_remove:
        df.loc[i, 'Sex_of_Driver'] = random.choice(
            lst_Sex_of_Driver)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12636\2602482476.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sex_of_Driver'].fillna(value=pd.Series(random_values,

# %%
# Xu ly Junction_Location
unique_values = df['Junction_Location'].dropna().unique()

# Random các giá trị từ cột
random_values = np.random.choice(
    unique_values, size=df['Junction_Location'].isnull().sum())
df['Junction_Location'].fillna(value=pd.Series(random_values,
                                           index=df.index[df['Junction_Location'].isnull()]), inplace=True)

lst_Junction_Location = list(unique_values)
for value in lst_remove:
    if value in lst_Junction_Location:
        lst_Junction_Location.remove(value)

for i, v in df.iterrows():
    if v['Junction_Location'] in lst_remove:
        df.loc[i, 'Junction_Location'] = random.choice(
            lst_Junction_Location)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12636\1148787430.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Junction_Location'].fillna(value=pd.Series(random_values,

# %%
df.to_csv('./Vehicle.csv', index=False)
